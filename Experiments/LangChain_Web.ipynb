# %%
from langchain_community.document_loaders import OnlinePDFLoader
from langchain.document_loaders import WebBaseLoader
from langchain.indexes import VectorstoreIndexCreator
from langchain_openai import OpenAIEmbeddings
import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
loader = OnlinePDFLoader("https://arxiv.org/pdf/2302.03803.pdf")
data = loader.load

# %%
loader = WebBaseLoader("https://www.nature.com/articles/s41567-022-01788-5.epdf?sharing_token=ube1KozTYa5LaC9cu6hUTNRgN0jAjWel9jnR3ZoTv0NVOvMSmh5IwcU6Uxmom-KR2i-Pcwh_ETc6--qXhoO5LUGumCj0CT7GiaXaqsPr0FAEGtEInUThPONICh3K7Yk7QT9j7819reQGUGm4B7YVD61HSBoWLK0qWbTG__eeIcs%3D")
index = VectorstoreIndexCreator().from_loaders([loader])
index.query("What are the key points in this article?")
# Out:
# Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# '\n1. The article discusses the concept of simulating physical systems and how it relates to reality.\n2. It explores the limitations and challenges of simulating complex systems accurately.\n3. The article also discusses the potential benefits of using simulations in various fields, such as physics and engineering.\n4. It highlights the importance of understanding the underlying principles and assumptions in simulations.\n5. The article also touches on the ethical implications of using simulations in decision-making processes.\n6. It concludes by emphasizing the need for a balance between simulation and real-world experimentation.'

# %%
data = loader.load()
data
# Out:
# [Document(page_content='\n\n\nThe flow from simulation to reality | Nature Physics\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n', metadata={'source': 'https://www.nature.com/articles/s41567-022-01788-5.epdf?sharing_token=ube1KozTYa5LaC9cu6hUTNRgN0jAjWel9jnR3ZoTv0NVOvMSmh5IwcU6Uxmom-KR2i-Pcwh_ETc6--qXhoO5LUGumCj0CT7GiaXaqsPr0FAEGtEInUThPONICh3K7Yk7QT9j7819reQGUGm4B7YVD61HSBoWLK0qWbTG__eeIcs%3D', 'title': 'The flow from simulation to reality | Nature Physics', 'description': 'Fluid simulations today are remarkably realistic. In this Comment I discuss some of the most striking results from the past 20 years of computer graphics research that made this happen.', 'language': 'en'})]

# %%
loader = WebBaseLoader("https://ayr.ai/company/management")
index = VectorstoreIndexCreator().from_loaders([loader])
index.query("Tell me the summary of this page")
# Out:
# " This page is about AYR, a next-generation Intelligent Document Processing (IDP) company, and its mission to change the future of work for the better. It includes information about the company's leadership team, services, and clients, as well as a video interview with one of the co-founders discussing the company's founding and goals."

# %%
data = loader.load()
data
# Out:
# [Document(page_content='\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLeadership Team - AYR.ai\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to content\n\n\n\n\n\n\n\n\n\n \n \n\n\n\n\n\n\n\n\n \n \nSolutions\n\nAdvantages The SingularityAI Platform Use Cases\n\nResources\n\nAll Resources Blog\n\nCompany\n\nAbout News Contact Us\n\n\n\n\n\n\nX\n \n\n\n\n\n\n\n\n \n\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\tSchedule Demo\t\t\t\t\n\n \n\n\n\n\n\n\n\n \n \n\n\n\n\n\n\n\n\n \n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAbout Us \n\n\n\n AYR (formerly Singularity Systems) unlocks the value hidden in your unstructured data. Since our founding in 2018, AYR has been at the forefront of innovation in the AI, machine learning, and automation industries. \n\n\n\n\n\n\n\n\n\n\n\nWith its world-class team of scientists and developers, AYR has pioneered new AI techniques that have modernized and democratized intelligent document proce
# ...

# %%
loader = WebBaseLoader("https://www.scu.edu/bulletin/undergraduate/chapter-5/computer-science-and-engineering.html#59ffa8ec905c")
index = VectorstoreIndexCreator().from_loaders([loader])
index.query("What are the prerequisites to COEN188")
# Out:
# /Users/seanwu/anaconda3/envs/RAG/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.embeddings.openai.OpenAIEmbeddings` was deprecated in langchain-community 0.1.0 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(
# ' A grade of C- or better in CSEN/COEN 146 and CSEN/COEN 177.'

# %%
data = loader.load()
data
# Out:
# [Document(page_content='\n\n\nSCU Undergraduate Bulletin 2023-24 -  Computer  Science  and  Engineering\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n SCU Undergraduate Bulletin 2023-24 \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n2023-2024:  Undergraduate  Bulletin Chapter 1:  University Mission Santa Clara University Academic Programs Centers of Distinction Faculty Student Body Alumni Campus Chapter 2:  Transformative Experiences and Learning Resources The Core Curriculum The  Residential  Experience Campus  Ministry Global  Engagement Career  Center Campus  Recreation Intercollegiate AthleticsSCU Presents Center for  Student  Involvement Chartered Student Organizations Office for  Multicultural  Learning University Honors ProgramLEAD Scholars Program Office of Student Fellowships Peer  Educator  Program Domestic Public Sector Studies Programs Academic Advising and Learning Resources The Writing Center Information Services Office  of  Accessible  Education (OAE) Cowell Center University L
# ...
